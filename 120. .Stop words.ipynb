# %% [markdown]
# # Stop words

# %% [raw]
# Stop words are frequently used words in a language such as "a", "the", "so" etc. (in engllish) that do not add a lot of value to certain NLP tasks. Hence it is better to remove them during pre-processing stage.

# %% [raw]
# stop words are words that are considered to be common and of little value in terms of conveying meaningful information about the content of a document or sentence. These words are typically filtered out or ignored during the text processing pipeline to improve the efficiency of algorithms and to focus on the more significant words.

# %% [raw]
# "the", "is", "and", "of", "in", "a", etc. These words are so common that they occur frequently in almost all texts, regardless of the topic, and they don't contribute much to the overall meaning of the text.

# %% [raw]
# Removing stop words can help reduce the dimensionality of text data and improve the performance of tasks such as text classification, information retrieval, and topic modeling. However, it's important to note that the list of stop words may vary depending on the specific task and the language being analyzed. Additionally, in certain contexts, stop words might carry significance and should not be removed, so their removal should be done judiciously.

# %%
import spacy

from spacy.lang.en.stop_words import STOP_WORDS

STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("We just opened our wings, the flying part is coming soon")

for token in doc:
    if token.is_stop:
        print(token)
# Out:
# We
# just
# our
# the
# part
# is

# %%
def preprocess(text):
    doc = nlp(text)
    
    no_stop_words = [token.text for token in doc if not token.is_stop]
    return " ".join(no_stop_words)

# %%
preprocess("Musk wants time to prepare for a trial over his")
# Out:
# 'Musk wants time prepare trial'

# %%
preprocess("The other is not other but your divine brother")
# Out:
# 'divine brother'

# %% [markdown]
# # Remove stop words from pandas dataframe text column

# %%
import pandas as pd

df = pd.read_json("doj_press.json",lines=True)

df.shape
# Out:
# (13087, 6)

# %%
df.head(5)
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# ...

# %%
df = df[df["topics"].str.len() != 0]
df.head()
# Out:
#          id                                              title  \
# 4    18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7   14-1412  14 Indicted in Connection with New England Com...
# 19  17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22  15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23  17-1404  21st Century Oncology to Pay $26 Million to Se...
#
#                                              contents  \
# 4   The U.S. Department of Justice, the U.S. Envir...
# 7   A 131-count criminal indictment was unsealed t...
# 19  The United States Attorney’s Office for the Mi...
# 22  21st Century Oncology LLC, has agreed to pay $...
# 23  21st Century Oncology Inc. and certain of its ...
#
#                          date                                 topics  \
# 4   2018-07-09T00:00:00-04:00                          [Environment]
# 7   2014-12-17T00:00:00-05:00                  [Consumer Protection]
# ...

# %%
df.shape
# Out:
# (4688, 6)

# %%
df =df.head(100)
df.shape
# Out:
# (100, 6)

# %%
df["contents_new"] = df.contents.apply(preprocess)

# %%
df
# Out:
#           id                                              title  \
# 4     18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7    14-1412  14 Indicted in Connection with New England Com...
# 19   17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22   15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23   17-1404  21st Century Oncology to Pay $26 Million to Se...
# ..       ...                                                ...
# 316  15-1359  Alaska Plastic Surgeon Convicted of Wire Fraud...
# 318   16-396  Alaska Plastic Surgeon Sentenced to Prison for...
# 321   17-736  Alaskan Commercial Fishing Couple Charged with...
# 322   18-717  Alaskan Husband And Wife Plead Guilty To Willf...
# 324  16-1345        Alaskan Oncologist Indicted for Tax Evasion
#
#                                               contents  \
# 4    The U.S. Department of Justice, the U.S. Envir...
# 7    A 131-count criminal indictment was unsealed t...
# ...

# %%
len(df.contents[4])
# Out:
# 6286

# %%
len(df.contents_new[4])
# Out:
# 4810

# %%
df.contents[4][:300]
# Out:
# 'The U.S. Department of Justice, the U.S. Environmental Protection Agency (EPA), and the Rhode Island Department of Environmental Management (RIDEM) announced today that two subsidiaries of Stanley Black & Decker Inc.—Emhart Industries Inc. and Black & Decker Inc.—have agreed to clean up dioxin conta'

# %%
df.contents_new[4][:300]
# Out:
# 'U.S. Department Justice , U.S. Environmental Protection Agency ( EPA ) , Rhode Island Department Environmental Management ( RIDEM ) announced today subsidiaries Stanley Black & Decker Inc.—Emhart Industries Inc. Black & Decker Inc.—have agreed clean dioxin contaminated sediment soil Centredale Manor'

# %% [markdown]
# # (1) Sentiment detection: Not always but in some cases, based on your dataset it can change the sentiment of a sentence if you remove stop words

# %%
preprocess("this is a good movie")
# Out:
# 'good movie'

# %%
preprocess("this is not a good movie")
# Out:
# 'good movie'

# %% [markdown]
# # (2) Language translation: Say you want to translate following sentence from english to telugu. Before actual translation if you remove stop words and then translate, it will produce horrible result

# %%
preprocess("how are you doing dhaval?")
# Out:
# 'dhaval ?'

# %% [markdown]
# # (3) Chat bot or any Q&A system

# %%
preprocess("I don't find yoga mat on your website. Can you help?")
# Out:
# 'find yoga mat website . help ?'

# %% [markdown]
# # COMPLETED....!
